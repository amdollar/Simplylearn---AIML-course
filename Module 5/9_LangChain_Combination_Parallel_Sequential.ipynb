# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# %%
llm = ChatOpenAI(model='gpt-4o-mini')

# %%
breifing_template = PromptTemplate(
    input_variables=['questions'],
    template='''    You are my special AI Assistant. Act as a Doctor. Answer all queries in 2 sentences.
    Question: {question}'''
)

detailing_template = PromptTemplate(
    input_variables=['question'],
    template='''You are my special AI Assistant. Act as a Doctor. Answer all queries as detailed as possible.
    Question: {question}'''
)

summaryTemplate = PromptTemplate(
    input_variables=['question'],
    template="""    Give one-line summary for the answer to 
    {question}   """
)

# Chains:
chainA= breifing_template | llm
chainB= detailing_template | llm

seq1 = chainA | chainB

chainC = summaryTemplate | llm



parallelChain = RunnableParallel(detailed_explaination = seq1, summary = chainC)

response = parallelChain.invoke({
    "question": "What is DNA?"
})

# %%
response
# Out:
# {'detailed_explaination': AIMessage(content="DNA, or deoxyribonucleic acid, is the fundamental hereditary material found in nearly all living organisms, playing a crucial role in carrying the genetic blueprint vital for growth, development, and functioning. Here's a more detailed breakdown of DNA:\n\n### Structure of DNA\n1. **Double Helix**: DNA has a unique double-helix structure, resembling a twisted ladder. This structure was first described by James Watson and Francis Crick in 1953.\n   \n2. **Nucleotides**: The building blocks of DNA are nucleotides, which consist of three components:\n   - **Phosphate Group**: A phosphorous atom bonded to four oxygen atoms that links the nucleotides together.\n   - **Sugar Molecule**: Deoxyribose is the sugar component in DNA.\n   - **Nitrogenous Base**: There are four types of nitrogenous bases in DNA:\n     - **Adenine (A)**\n     - **Thymine (T)**\n     - **Cytosine (C)**\n     - **Guanine (G)**\n\n3. **Base Pairing**: The nitrogenous bases
# ...
