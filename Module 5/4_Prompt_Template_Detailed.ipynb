# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import OpenAI
from langchain_core.prompts import (
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)

# %%
# Test code to show the working of placeholders

system= SystemMessagePromptTemplate.from_template('Act as a {persona} professor. Your answers are in short Sentences.')
question = HumanMessagePromptTemplate.from_template('Tell me about {topic} in {points} points')

system.format(persona='math')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Test code to show the working of placeholders
# ----> 3 system= SystemMessagePromptTemplate('Act as a {persona} professor. Your answes are in short Sentences.')
#       4 question = HumanMessagePromptTemplate('Tell me about {topic} in {points} points')
#       6 system.format(persona='math')
#
# File c:\Users\thedo\anaconda3\Lib\site-packages\langchain_core\load\serializable.py:117, in Serializable.__init__(self, *args, **kwargs)
#     115 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     116     """"""  # noqa: D419  # Intentional blank docstring
# --> 117     super().__init__(*args, **kwargs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given
