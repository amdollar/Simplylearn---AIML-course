# %%
# 1. Load the files using Directory loader 
# 2. Read these files and make document
# 3. Create chunks for this document
# 4. Create embeddings for these chunks
# 5. Feed this embedded data to the VectorDatabase
# 6. Feed this Vector database as a RAG storage to the LLM
# 7. Use llm to fetch the response and get the queries answered


from langchain_community.document_loaders import TextLoader, DirectoryLoader
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
# from langchain.retrievers import EnsembleRetriever
from langchain_classic.retrievers import BM25Retriever, EnsembleRetriever
# from langchain_community.retrievers import BM25Retriever

dir = DirectoryLoader(path = './Dataset', loader_cls=TextLoader)
documents = dir.load()

# %%
# 2. Create chunks using RecursiveCharacterTextSplitter class

splitter = RecursiveCharacterTextSplitter(chunk_size = 100, chunk_overlap = 20)
chunks = splitter.split_documents(documents)
len(chunks)
# Out:
# 11

# %%
# 3. Create embeddings from these Chunks using OpenAIEmbeddings:
embeddings= OpenAIEmbeddings(model='text-embedding-3-small')
chunk_list = [chunk.page_content for chunk in chunks]

embedded_chunks = embeddings.embed_documents(chunk_list)

print(f'Shape of embedded_chunks : {len(embedded_chunks)}')
# Out:
# Shape of embedded_chunks : 11

# %%
# 4. Feed these embedded data to the VectorStorage

storage = FAISS.from_documents(chunks, embeddings)

res = storage.similarity_search('What is the buffet breakfast timings in our hotel ? ', k=2)

for doc in res:
    print(doc.page_content)


# Initialize the Retriever: The retriever is typically an interface around your vector store that you can configure with specific parameters, such as the number of documents to fetch (top-k).
# Out:
# Buffet breakfast is served daily from 7am to 10am.
# Room service is available 24 hours.
# Sunday brunch is from 11am to 3pm.

# %%
# Next task is to build domain specific retrievers:
# 1. Setup your keywoard retriever: (BM25)

bm25_retriever =   BM25Retriever.from_documents(chunks)
bm25_retriever.k = 3

# 2. Setup sementic retriever:
retriever = storage.as_retriever(search_kwargs={'k': 3})

# 3. Create Domain Specific Ensemble:

ensemble_retriever = EnsembleRetriever(
    retrievers=[retriever, bm25_retriever],
    weights = [0.5, 0.5] 
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\thedo\anaconda3\Lib\site-packages\langchain_community\retrievers\bm25.py:55, in BM25Retriever.from_texts(cls, texts, metadatas, ids, bm25_params, preprocess_func, **kwargs)
#      54 try:
# ---> 55     from rank_bm25 import BM25Okapi
#      56 except ImportError:
#
# ModuleNotFoundError: No module named 'rank_bm25'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Next task is to build domain specific retrievers:
#       2 # 1. Setup your keywoard retriever: (BM25)
# ----> 4 bm25_retriever =  BM25Retriever.from_documents(chunks)
#       6 # 2. Setup sementic retriever:
#       7 retriever = storage.as_retriever(search_kwargs={'k': 3})
#
# File c:\Users\thedo\anaconda3\Lib\site-packages\langchain_community\retrievers\bm25.py:102, in BM25Retriever.from_documents(cls, documents, bm25_params, preprocess_func, **kwargs)
#      88 """
#      89 Create a BM25Retriever from a list of Documents.
#      90 Args:
#    (...)     97     A BM25Retriever instance.
#      98 """
#      99 texts, metadatas, ids = zip(
#     100     *((d.page_content, d.metadata, d.id) for d in documents)
#     101 )
# --> 102 return cls.from_texts(
#     103     texts=texts,
#     104     bm25_params=bm25_params,
#     105     metadatas=metadatas,
#     106     ids=ids,
#     107     preprocess_func=preprocess_func,
#     108     **kwargs,
#     109 )
#
# File c:\Users\thedo\anaconda3\Lib\site-packages\langchain_community\retrievers\bm25.py:57, in BM25Retriever.from_texts(cls, texts, metadatas, ids, bm25_params, preprocess_func, **kwargs)
#      55     from rank_bm25 import BM25Okapi
#      56 except ImportError:
# ---> 57     raise ImportError(
#      58         "Could not import rank_bm25, please install with `pip install "
#      59         "rank_bm25`."
#      60     )
#      62 texts_processed = [preprocess_func(t) for t in texts]
#      63 bm25_params = bm25_params or {}
#
# ImportError: Could not import rank_bm25, please install with `pip install rank_bm25`.
