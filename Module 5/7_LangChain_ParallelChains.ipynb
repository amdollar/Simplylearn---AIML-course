# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate
from langchain_core.runnables import RunnableParallel
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model = 'gpt-4o-mini', temperature=0.4)

# %%
# creation of one chain:

system_message = SystemMessagePromptTemplate.from_template('Act as a {persona}, your answers are short and concise.')
human_message = HumanMessagePromptTemplate.from_template('What is the best way of learning {topic}, tell me in {points} points.')

message = [system_message, human_message]

template = ChatPromptTemplate(message)

chain1 = template | llm | StrOutputParser()

# %%
system_message_2 = SystemMessagePromptTemplate.from_template('Act as a {persona}.')
human_message2 = HumanMessagePromptTemplate.from_template('Give me {count} posts for social media platform: {platform}, on {topic}, keep the tone logical and funny.')

message2 = [system_message_2, human_message2]


template = ChatPromptTemplate(message2)

chain2 = template | llm | StrOutputParser()

# %%
# class to build the final chain:
finalchain = RunnableParallel(facts = chain1, posts = chain2)

output = finalchain.invoke({
    'persona':'Boxing Champion',
    'topic': 'Shadow Boxing',
    'points':'4',
    'persona':'Top Social Media Manager',
    'count':'4',
    'platform':'X/Twitter',
    'topic':'Vibe coding'
})

print(output)
# Out:
# {'facts': "1. **Official Documentation**: Start with the Vibe documentation to understand the fundamentals and syntax.\n\n2. **Online Tutorials**: Utilize platforms like YouTube or coding websites for step-by-step video tutorials.\n\n3. **Practice Projects**: Build small projects to apply what you've learned and reinforce your skills.\n\n4. **Join Communities**: Engage in forums or social media groups to ask questions, share knowledge, and collaborate with others.", 'posts': 'Sure! Here are four posts for X/Twitter about Vibe coding that blend a logical approach with a touch of humor:\n\n---\n\n**Post 1:**\n🚀 Just started my journey into Vibe coding! It’s like regular coding, but with more good vibes and fewer bugs. 🐞✨ Remember, if your code doesn’t vibe, it’s time to jive! #VibeCoding #GoodVibesOnly\n\n---\n\n**Post 2:**\nWhy did the coder break up with their code? 🤔 It just wasn’t vibing anymore! 💔✨ Time to refactor that relationship! #VibeCoding #CodeLove\n\n---\n\n**Post 3:**\nVibe coding tip: If your code is throwing errors, just tell it to “chill.” 😎 Sometimes all it needs is a little positive energy! #CodingHumor #VibeCheck\n\n---\n\n**Post 4:**\nDebugging in Vibe coding: When you find a bug, just send it some good vibes and hope it finds its way home. 🐛✌️ Remember, every bug is just a feature waiting for a little love! #VibeCoding #DebuggingLife\n\n--- \n\nFeel free to adjust any details to better fit your audience!'}
