# %%
from dotenv import load_dotenv, find_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (SystemMessagePromptTemplate,
                                    HumanMessagePromptTemplate,
                                    PromptTemplate,
                                    ChatPromptTemplate)
from langchain_core.output_parsers import StrOutputParser

load_dotenv(find_dotenv())

llm = ChatOpenAI(model='gpt-4o-mini')

# %%
chat_template = ChatPromptTemplate.from_template('{prompt}')
chain = chat_template | llm | StrOutputParser()

response  = chain.invoke({'prompt': 'Hi My name is Anurag.'})
response
# Out:
# 'Hi Anurag! How can I assist you today?'

# %%
response = chain.invoke('What is my name ?')
response
# Out:
# "I'm sorry, but I don't have access to personal information unless you share it with me. How can I assist you today?"

# %%
about = "My name is Anurag, I work in Principal."

# %% [markdown]
# Runnable With Message History
# In order to properly set this up there are two main things to consider:
#
# How to store and load messages?
# What is the underlying Runnable you are wrapping and what are its inputs/outputs?

# %%
from langchain_core.messages import (SystemMessage, HumanMessage)
from langchain_core.runnables import RunnableWithMessageHistory
from langchain_community.chat_message_histories import SQLChatMessageHistory

# %%
def get_session_history(session_id):
    return SQLChatMessageHistory(session_id, 'sqlite:///chat_history.db')

# %%
runnable_with_history = RunnableWithMessageHistory(chain, get_session_history)

# %%
user_id = 'anurag_awasthi'
history = get_session_history(user_id)

history.get_messages()
# Out:
# [HumanMessage(content='My name is Anurag, I work in Principal.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Hello Anurag! It's nice to meet you. How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='where do you think I work ? ', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='It seems you mentioned working at Principal. How can I help you with something related to your work or any other topic?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='My name is Anurag, I work in Principal.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="It looks like you are providing a series of messages from a conversation between a human (Anurag) and an AI. The conversation is mostly centered around Anurag's workplace, which is Principal. How can I assist you further with this conversation or any other questions you might have?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='where do you think I work ? ', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="It seems like you're sharing a conversation between yourself and an AI. In the conversation, you introduced yourself and mentioned that you work at Principal. If you have any specific questions or topics you'd like to discuss, whether it's related to your work or something else, feel free to ask! How can I assist you today?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='what is my name ? ', additional_kwargs={}, response_metadata={}),
#  AIMessage(content="It seems your name is Anurag, as you've mentioned it in the conversation. How can I assist you further?", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]

# %%
user_id = 'anurag_awasthi'
history= get_session_history(user_id)

runnable_with_history.invoke([HumanMessage(content = about)],
                             config = {'configurable': {'session_id': user_id}})
# Out:
# "Hello Anurag! It seems we've been discussing your name and your workplace, which is Principal. How can I assist you further today? Do you have any specific questions or topics in mind?"

# %%
user_id = 'anurag_awasthi'
history= get_session_history(user_id)

runnable_with_history.invoke([HumanMessage(content = 'where do you think I work ? ')],
                             config = {'configurable': {'session_id': user_id}})
# Out:
# "It looks like you're repeating the same questions and statements about your name, workplace, and asking where you work. Would you like to focus on something specific related to your work at Principal or any other topic? I'm here to help!"

# %%
# Create two user sessions with some informations.

# %%
outputa1= runnable_with_history.invoke(input='Hi My name is Anurag, and I love sucheta',
                                       config={'configurable': {'session_id' : 'anurag'}})

outputa2 = runnable_with_history.invoke(input='I am a software engineer and I live in hyderabad',
                                        config= {'configurable': {'session_id': 'anurag'}})

# %%
output_a = runnable_with_history.invoke(('What do you think could be my hobby ?'),
                             config={'configurable':{'session_id': 'anurag'}})

print(output_a)

output_s = runnable_with_history.invoke(('What places should I explore based on my location and preferences, not more than overnight.'),
                                        config= {'configurable': {'session_id':'suchee'}})

print(output_s)
# Out:
# It seems you're quite interested in exploring your hobbies! Since you're a software engineer, here are a few hobbies that might resonate with you:
#
# 1. **Coding Projects**: You might enjoy working on personal projects, whether it's building apps, contributing to open source, or experimenting with new technologies.
#
# 2. **Gaming**: Many software engineers find gaming a great way to unwind and have fun.
#
# 3. **Reading and Learning**: You could have an interest in reading tech blogs, books, or taking online courses to expand your knowledge and skills.
#
# 4. **Outdoor Activities**: Some tech enthusiasts enjoy outdoor activities like hiking, biking, or just spending time in nature.
#
# 5. **Creative Hobbies**: Engaging in creative pursuits such as photography, music, or art could also be fulfilling.
#
# Do any of these ideas resonate with you, or is there something else you particularly enjoy doing in your free time?
# It looks like you're interested in exploring nearby places for an overnight trip from Delhi, and you've asked several times for recommendations. Just to recap the suggestions:
#
# 1. **Agra**: About 3-4 hours away, famous for the Taj Mahal and Agra Fort.
#
# 2. **Jaipur**: Approximately 5 hours from Delhi, known as the Pink City with beautiful forts and markets.
#
# 3. **Rishikesh**: A 5-6 hour drive, perfect for nature lovers and spiritual seekers, offering activities like yoga and river rafting.
#
# 4. **Manesar**: Just about an hour away, great for a quick getaway with resorts offering pools to beat the heat.
#
# 5. **Lansdowne**: A serene hill station about 6-7 hours from Delhi, ideal for nature walks and relaxation.
#
# 6. **Neemrana**: Located 2-3 hours away, it offers a historic fort that you can explore and stay in.
#
# If you'd like more insights into any specific place or have other preferences in mind, please let me know!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
