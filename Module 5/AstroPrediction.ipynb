# %% [markdown]
# This is a GenAI based application, this app will take:
# Full name
# Date of birth
# Time of birth
# Birth place as inputs and Generate a Astological report of the user.

# %%
import os
from datetime import datetime
from typing import Dict
os.environ['API_KEY']= 'AIzaSyDxIJyqMmEnlEeU5Dzvdr_lt6FOlRTFIl8'

# %%
# %pip install google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['API_KEY'])

model = genai.GenerativeModel(model_name='gemini-2.5-flash-lite')

# %%
class AstrologyApp():
    '''Main class for astrology application.'''

    def __init__(self):
        self.user_info = {}

    

    def get_user_input(self)-> Dict[str, str]:
        '''Collect personal details from the user.'''

        print('=' * 60)
        print('Welcome to Astrology application.')
        print('=' * 60)

        name = input('Please enter your name: ').strip()
        dob = input('Enter your date of birth: ').strip()
        dot = input('Enter your birth time: ').strip()
        birth_place = input('Enter your birth place: ').strip()

        self.user_info= {
            'name':name,
            'dob': dob,
            'dot': dot,
            'birth_place': birth_place
        }
        print(self.user_info)

        return self.user_info

    def validate_user_inputs(self):

        if not self.user_info.get('name'):
            print('Error: Name is required.')
            return False

        if not self.user_info.get('dob'):
            print('Error: Date Of Birth is required.')
            return False
        
        try:
            datetime.strptime(self.user_info["dob"], "%Y-%m-%d")
        except ValueError:
            print("Error: Invalid date format. Please use YYYY-MM-DD")
            return False

        if not self.user_info.get('birth_place'):
            print('Error: Birth Place is required.')
            return False

        return True

    def generate_ai_prompt(self)-> str:
        '''Generate a comprehensive prompt for astrological reading'''

        name= self.user_info['name']
        dob = self.user_info['dob']
        tob = self.user_info['dot']
        birth_place = self.user_info['birth_place']

        prompt = f"""You are an experienced astrologer providing a personalized astrological reading.

            User Details:
            - Name: {name}
            - Birth Date: {dob}
            - Birth Time: {tob if tob != "Unknown" else "Not provided"}
            - Birth Place: {birth_place}

            Please provide a comprehensive astrological reading that includes:

            1. **Birth Chart Overview**: A general interpretation based on the birth date and location
            2. **Sun Sign Analysis**: Personality traits and core characteristics
            3. **Planetary Influences**: Key planetary positions and their meanings
            4. **Life Guidance**: Practical insights and advice based on astrological indicators
            5. **Answer to Question**: Specific response to the user's question if provided

            Make the reading personal, insightful, and encouraging. Use astrological terminology appropriately but explain concepts clearly for someone who may not be deeply familiar with astrology.

            Format your response with clear sections and make it engaging and meaningful."""

        return prompt

    def get_llm_response(self, prompt: str)-> str:
        
        response = model.generate_content(prompt)
        print('Generating your astrological readings....')

        return response.text

    def display_readings(self, response: str):
        '''Method is to display the readings from the LLM '''
        print('\n' + '=' * 60)
        print('Your Astrological Readings:')
        print('=' * 60)
        print(response)
        print('=' * 60)

        # Option to save:
        save = input('Do you want to save this reading in a file ? (y/n): ').strip().lower()
        if save == 'y':
            self.save_readings_in_file(response)


    def save_readings_in_file(self, reading:str):
        '''Method to save these readings in a file'''
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f'astrology_readings_{self.user_info['name'].replace(' ', '_')}_{timestamp}.txt'

        try:
            with open(filename, 'w', encoding= 'utf-8') as f:
                f.write(f'Astrological Readings for :{self.user_info['name']}\n')
                f.write(f'Generated on {timestamp} \n')
                f.write("=" * 60 + "\n\n")
                f.write(f"Birth Details:\n")
                f.write(f"  Date: {self.user_info['dob']}\n")
                f.write(f"  Time: {self.user_info['tob']}\n")
                f.write(f"  Place: {self.user_info['birth_place']}\n")
                f.write("=" * 60 + "\n\n")
                f.write(reading)
            
            print(f"✅ Reading saved to: {filename}")
        except Exception as e:
            print('Unable to save the file.')


    def run(self):
        '''To run the application method'''
        self.get_user_input()

        # validate the user inputs:
        if not self.validate_user_inputs():
            print('Please correct the errors above and try again.')
            return 

        # Generate Prompt:
        prompt = self.generate_ai_prompt()

        # Generate LLM Response:
        response = self.get_llm_response(prompt)

        # Display readings:
        self.display_readings(response)

# %%
def main():
    '''Main pipeline of application'''
    app = AstrologyApp()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Welcome to Astrology application.
# ============================================================
# {'name': 'sucheta', 'dob': '2001-02-01', 'dot': '12:00', 'birth_place': 'lucknow, india'}
# Generating your astrological readings....
#
# ============================================================
# Your Astrological Readings:
# ============================================================
# Dearest Sucheta,
#
# It is a pleasure and an honor to delve into the celestial tapestry woven for you on February 1st, 2001, at 12:00 PM in Lucknow, India. The stars, in their silent dance, have much to reveal about your unique journey, your innate strengths, and the potentials that lie ahead. Let's unfurl this cosmic map together.
#
# ***
#
# ## Your Personalized Astrological Reading
#
# ### 1. Birth Chart Overview: A Glimpse into Your Cosmic Blueprint
#
# Your birth chart is a snapshot of the heavens at the exact moment and place of your birth, a unique fingerprint etched in the stars. For you, Sucheta, born in Lucknow on February 1st, 2001, at noon, we see a fascinating interplay of energies. The placement of planets and their relationships to each other paints a picture of your core nature, your life path, and the experiences that will shape you.
#
# This chart suggests a soul that is both **practical and deeply idealistic**, with a strong desire to understand the underlying truths of life. You have a keen intellect and a natural inclination towards learning and exploration. There's a blend of nurturing energy with a drive for independent thought and action. It's a chart that promises growth through learning, connection, and the courage to express your individuality.
#
# ### 2. Sun Sign Analysis: Your Radiant Core – Aquarius
#
# Your Sun sign, Sucheta, is **Aquarius**, the Water Bearer. This is your core identity, the fundamental expression of your life force and ego. Aquarians are known for their **innovative spirit, their intellectual curiosity, and their humanitarian ideals.**
#
# *   **Key Traits of Your Aquarius Sun:**
#     *   **Originality & Independence:** You possess a mind that thinks outside the box. You're not one to follow the crowd blindly, preferring to forge your own path and question established norms.
#     *   **Intellectual Prowess:** Your mind is a powerful tool. You enjoy learning, exploring new ideas, and engaging in stimulating conversations. You have a natural talent for analysis and problem-solving.
#     *   **Humanitarianism:** A deep-seated desire to contribute to the greater good often fuels your actions. You care about society, fairness, and the well-being of others. You can be a champion for the underdog.
#     *   **Unconventional Nature:** You might express yourself in ways that others find unique or even eccentric. This is a sign of your authentic self shining through.
#     *   **Friendship Focused:** Friendships are incredibly important to you. You value loyalty, intellectual connection, and shared ideals with your close circle.
#     *   **Detached Observation:** While you care deeply, you also have a capacity for objective observation, which allows you to see situations from multiple perspectives.
#
# **Encouragement:** Embrace your uniqueness, Sucheta! Your innovative thinking is a gift. Don't be afraid to stand out. Your desire to make a positive impact is a powerful motivator.
#
# ### 3. Planetary Influences: The Cosmic Orchestra Within You
#
# Let's explore some of the key planetary positions in your chart:
#
# *   **Mercury in Aquarius:** Your mind is sharp, analytical, and original. You communicate your ideas in a clear, sometimes unconventional manner. You likely have a knack for technology and a fascination with abstract concepts. This placement amplifies your Aquarian traits, making your thinking even more progressive and forward-thinking.
# *   **Venus in Pisces:** This is a beautiful placement, Sucheta. Venus here softens your Aquarian edges with immense compassion, creativity, and romantic idealism. You have a deep capacity for empathy and a love for beauty in all its forms – art, music, nature. Your relationships are likely to be characterized by gentleness, understanding, and a touch of enchantment. You are drawn to spiritual or artistic pursuits.
# *   **Mars in Taurus:** Your energy and drive are grounded and persistent. When you set your mind to something, you approach it with determination and a steady pace. You are not easily rushed but possess incredible stamina. This placement can bring a strong will and a desire for security and comfort, manifesting in your actions.
# *   **Jupiter in Gemini:** This is a potent influence for learning and growth. Jupiter in Gemini expands your horizons through communication, travel, and the acquisition of diverse knowledge. You are naturally curious and have a knack for absorbing information from various sources. Your optimism and good fortune often come through learning, sharing ideas, and engaging in intellectual exploration.
# *   **Saturn in Taurus:** Saturn here brings a sense of responsibility and a need for tangible security. You learn lessons about patience, building, and the value of material resources. You have a strong work ethic and are capable of creating lasting structures and stability in your life, though it may require diligent effort.
#
# **Understanding the Synergy:** Notice how your intellectual Aquarian Sun is beautifully complemented by your Venus in Pisces, bringing empathy and creativity to your innovative mind. Your Mars in Taurus provides the steady resolve to bring your ideas into reality, while Jupiter in Gemini fuels your continuous learning and exploration.
#
# ### 4. Life Guidance: Navigating Your Path with Wisdom
#
# Sucheta, your chart suggests a life rich with intellectual stimulation, creative expression, and the potential for meaningful connections. Here are some practical insights to guide you:
#
# *   **Embrace Your Visionary Nature:** You have a unique way of seeing the world, and this is a gift. Don't shy away from your original ideas, even if they seem unconventional to others. The world needs your fresh perspectives.
# *   **Nurture Your Creative Spirit:** With Venus in Pisces, your artistic and imaginative faculties are strong. Whether it's through art, music, writing, or simply how you approach life, allow your creativity to flow. This will bring you immense joy and fulfillment.
# *   **Balance Idealism with Practicality:** Your Aquarian idealism can sometimes soar high. Ground yourself by consciously connecting with the practical world, especially as indicated by your Taurus placements. Building tangible results will be important for your sense of accomplishment.
# *   **Cultivate Deep Connections:** While you value your independence, your chart also speaks to the importance of meaningful relationships. Seek out kindred spirits who appreciate your intellect and share your values. Your capacity for empathy, from Venus in Pisces, will make you a wonderful friend and partner.
# *   **Continuous Learning is Key:** Your Jupiter in Gemini thrives on knowledge. Make lifelong learning a priority. Read widely, engage in discussions, and explore new subjects. This will not only broaden your understanding but also bring you opportunities for growth and serendipitous encounters.
# *   **Patience with Progress:** Saturn in Taurus reminds us that true growth and stability take time and consistent effort. Be patient with yourself and your endeavors. Celebrate small victories and trust the process of building something lasting.
#
# ### 5. Answer to Your Question: (If you had asked one)
#
# *(As no specific question was provided, I will leave this section as a placeholder. If Sucheta had asked a question, I would provide a targeted response here, drawing from the relevant aspects of her chart.)*
#
# ***
#
# Sucheta, your astrological chart is a testament to a soul with a bright intellect, a compassionate heart, and a desire to make a difference. The energies present are conducive to innovation, deep connection, and continuous personal evolution. Trust your intuition, embrace your unique brilliance, and know that the universe supports your journey of learning, creating, and contributing.
#
# May your path be filled with insight, joy, and the realization of your highest potential.
#
# With warm celestial blessings,
#
# Your Astrologer
# ============================================================
