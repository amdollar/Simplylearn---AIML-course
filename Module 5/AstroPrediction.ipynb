# %% [markdown]
# This is a GenAI based application, this app will take:
# Full name
# Date of birth
# Time of birth
# Birth place as inputs and Generate a Astological report of the user.

# %%
import os
from datetime import datetime
from typing import Dict
os.environ['API_KEY']= 'AIzaSyC5zwRMnxke1g-2SMkbA6BW5mBlu4BXRk8'

# %%
# %pip install google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['API_KEY'])

model = genai.GenerativeModel(model_name='gemini-2.5-flash-lite')

# %%
class AstrologyApp():
    '''Main class for astrology application.'''

    def __init__(self):
        self.user_info = {}

    

    def get_user_input(self)-> Dict[str, str]:
        '''Collect personal details from the user.'''

        print('=' * 60)
        print('Welcome to Astrology application.')
        print('=' * 60)

        name = input('Please enter your name: ').strip()
        dob = input('Enter your date of birth: ').strip()
        dot = input('Enter your birth time: ').strip()
        birth_place = input('Enter your birth place: ').strip()

        self.user_info= {
            'name':name,
            'dob': dob,
            'dot': dot,
            'birth_place': birth_place
        }
        print(self.user_info)

        return self.user_info

    def validate_user_inputs(self):

        if not self.user_info.get('name'):
            print('Error: Name is required.')
            return False

        if not self.user_info.get('dob'):
            print('Error: Date Of Birth is required.')
            return False
        
        try:
            datetime.strptime(self.user_info["dob"], "%Y-%m-%d")
        except ValueError:
            print("Error: Invalid date format. Please use YYYY-MM-DD")
            return False

        if not self.user_info.get('birth_place'):
            print('Error: Birth Place is required.')
            return False

        return True

    def generate_ai_prompt(self)-> str:
        '''Generate a comprehensive prompt for astrological reading'''

        name= self.user_info['name']
        dob = self.user_info['dob']
        tob = self.user_info['dot']
        birth_place = self.user_info['birth_place']

        prompt = f"""You are an experienced astrologer providing a personalized astrological reading.

            User Details:
            - Name: {name}
            - Birth Date: {dob}
            - Birth Time: {tob if tob != "Unknown" else "Not provided"}
            - Birth Place: {birth_place}

            Please provide a comprehensive astrological reading that includes:

            1. **Birth Chart Overview**: A general interpretation based on the birth date and location
            2. **Sun Sign Analysis**: Personality traits and core characteristics
            3. **Planetary Influences**: Key planetary positions and their meanings
            4. **Life Guidance**: Practical insights and advice based on astrological indicators
            5. **Answer to Question**: Specific response to the user's question if provided

            Make the reading personal, insightful, and encouraging. Use astrological terminology appropriately but explain concepts clearly for someone who may not be deeply familiar with astrology.

            Format your response with clear sections and make it engaging and meaningful."""

        return prompt

    def get_llm_response(self, prompt: str)-> str:
        
        response = model.generate_content(prompt)
        print('Generating your astrological readings....')

        return response.text

    def display_readings(self, response: str):
        '''Method is to display the readings from the LLM '''
        print('\n' + '=' * 60)
        print('Your Astrological Readings:')
        print('=' * 60)
        print(response)
        print('=' * 60)


    def run(self):
        '''To run the application method'''
        self.get_user_input()

        # validate the user inputs:
        if not self.validate_user_inputs():
            print('Please correct the errors above and try again.')
            return 

        # Generate Prompt:
        prompt = self.generate_ai_prompt()

        # Generate LLM Response:
        response = self.get_llm_response(prompt)

        # Display readings:
        self.display_readings(response)

# %%
def main():
    '''Main pipeline of application'''
    app = AstrologyApp()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Welcome to Astrology application.
# ============================================================
# {'name': 'Anurag', 'dob': '1996-02-01', 'dot': '12:32', 'birth_place': 'Unnao, India'}
# Generating your astrological readings....
#
# ============================================================
# Your Astrological Readings:
# ============================================================
# Namaste Anurag, and welcome! It's a pleasure to offer you a glimpse into the celestial tapestry that was woven at the moment of your birth. Your birth chart is a unique map of the cosmos, a snapshot of the energies at play that have shaped and continue to influence your journey. Let's delve into its depths together.
#
# ## Anurag's Cosmic Blueprint: A Personalized Astrological Reading
#
# ### 1. Birth Chart Overview: A Unique Cosmic Impression
#
# Anurag, born on February 1st, 1996, in Unnao, India, at 12:32 PM, you have a birth chart that speaks of a dynamic and insightful individual. The very act of your birth at noon signifies a connection to the visible world and a drive to make your mark. Unnao, with its specific geographical coordinates, anchors your chart to earthly realities and cultural nuances that are part of your heritage.
#
# Your chart reveals a beautiful interplay of intellectual curiosity and a desire for emotional security. There's a natural inclination towards understanding how things work, combined with a deep-seated need to feel connected and grounded in your relationships and your environment. The energies present suggest a path where you can effectively blend your thinking mind with your feeling heart.
#
# ### 2. Sun Sign Analysis: The Aquarius Spark
#
# Your **Sun Sign is Aquarius**. This is your core identity, the fundamental essence of who you are, and the energy you are here to express. Aquarians are known for their:
#
# *   **Innovation and Originality:** You possess a brilliant, unconventional mind that thrives on new ideas and approaches. You're often ahead of your time, seeing possibilities where others see limitations.
# *   **Humanitarian Spirit:** There's a deep-seated concern for the collective well-being. You care about making the world a better place and often champion causes that benefit humanity.
# *   **Intellectual Prowess:** You have a sharp, analytical intellect and a thirst for knowledge. You enjoy dissecting information, understanding complex systems, and engaging in stimulating conversations.
# *   **Independence and Individuality:** You value your freedom and your unique perspective. You're not one to blindly follow the crowd and prefer to forge your own path.
# *   **Detached Objectivity:** While you care deeply, you can also approach situations with a certain objective distance, allowing you to see things clearly without being overly swayed by emotion.
#
# Anurag, your Aquarian Sun gifts you with a unique perspective and a drive to bring about positive change. Embrace your individuality and don't be afraid to challenge the status quo when you believe in a better way.
#
# ### 3. Planetary Influences: Guiding Lights in Your Chart
#
# Let's explore some of the key planetary placements and what they signify for you:
#
# *   **Moon in Scorpio:** This is a profoundly significant placement, Anurag. While your Sun is in the airy, intellectual Aquarius, your **Moon in Scorpio** reveals the depths of your emotional world. This means:
#     *   **Intense Emotions:** Your feelings run deep and are often very potent. You experience emotions with great intensity and are not afraid to delve into the darker, more complex aspects of life.
#     *   **Desire for Transformation:** Scorpio Moons have a natural inclination towards psychological exploration and transformation. You are drawn to understanding the hidden, the mysterious, and the processes of regeneration.
#     *   **Loyalty and Devotion:** Once you give your trust, your loyalty is fierce and unwavering. You are deeply protective of those you love.
#     *   **Need for Emotional Security:** Despite the intensity, you crave a profound sense of emotional security and intimacy in your close relationships. Betrayal can be deeply wounding.
#     *   **Intuition:** You possess a powerful intuition and can often sense underlying motivations and truths that others miss.
#
#     The contrast between your Sun and Moon suggests a fascinating inner landscape. You have a rational, outward-facing intellect (Aquarius Sun), but your emotional core is passionate, investigative, and deeply feeling (Scorpio Moon). Learning to integrate these two powerful energies will be key to your fulfillment.
#
# *   **Ascendant (Rising Sign) in Libra:** Your Ascendant represents the mask you wear to the world and how you initially present yourself. With your **Ascendant in Libra**, you appear to others as:
#     *   **Diplomatic and Harmonious:** You exude an aura of charm, grace, and a desire for balance and fairness. You're skilled at mediation and strive to create peaceful environments.
#     *   **Appreciative of Beauty:** You have a natural aesthetic sensibility and are drawn to beauty, art, and pleasant surroundings.
#     *   **Focused on Relationships:** Your initial approach to life often involves considering others and seeking harmonious connections. You understand the give-and-take of partnerships.
#     *   **Seeking Justice:** Libras are ruled by Venus and have a strong sense of justice and equality. You will often stand up for what you believe is fair.
#
#     Your Libra Ascendant beautifully complements your Aquarian Sun, as both signs value harmony and fairness. It suggests you navigate the world with a desire for diplomacy and connection, even while your inner world is exploring deeper, more transformative currents.
#
# *   **Mercury in Pisces:** Your thinking and communication style is influenced by **Mercury in Pisces**. This indicates:
#     *   **Intuitive and Imaginative Communication:** Your mind is highly imaginative and intuitive. You might communicate through feelings, images, or metaphors rather than purely logical statements.
#     *   **Empathy in Expression:** You are likely to be very empathetic in your communication, able to understand and express the feelings of others.
#     *   **Artistic and Creative Expression:** Pisces Mercury lends itself to artistic pursuits, storytelling, and creative writing.
#     *   **Potential for Vagueness:** At times, your communication might be perceived as a bit vague or dreamy, as you process information on a more subtle, feeling level.
#
#     This placement adds a poetic and compassionate layer to your Aquarian intellect. You can blend logical thought with intuitive understanding, making you a compassionate communicator and a creative thinker.
#
# *   **Venus in Aquarius:** Your Venus placement governs your values, pleasures, and how you express love and affection. With **Venus in Aquarius**, you:
#     *   **Value Intellectual Connection in Love:** You are attracted to individuals who stimulate your mind and share your progressive ideals. Friendship is often the foundation of your romantic relationships.
#     *   **Express Love Unconventionally:** Your expressions of affection might be more platonic or based on shared interests and intellectual camaraderie rather than overt displays of passion.
#     *   **Seek Freedom in Relationships:** You need space and freedom within your partnerships. You don't like to feel stifled or controlled.
#     *   **Appreciate Uniqueness:** You are drawn to people who are individualistic and march to the beat of their own drum.
#
#     This reinforces your Aquarian Sun, highlighting your need for intellectual stimulation and a sense of freedom in all your relationships, including romantic ones.
#
# ### 4. Life Guidance: Navigating Your Cosmic Path
#
# Anurag, your birth chart presents a compelling blend of intellectualism, emotional depth, and a desire for connection. Here's some guidance to help you navigate your journey:
#
# *   **Integrate Your Mind and Heart:** The most significant guidance from your chart is to bridge the gap between your logical Aquarian Sun and your intense Scorpio Moon. Don't let your rational mind dismiss your deep emotions, and don't let your emotions overwhelm your analytical abilities. Learn to use your intuition (Scorpio Moon) to inform your innovative ideas (Aquarius Sun) and to understand the deeper motivations of others. This integration will lead to profound wisdom and authentic self-expression.
#
# *   **Embrace Your Transformative Power:** Your Scorpio Moon gives you a natural capacity for transformation and healing, both for yourself and others. You are not afraid of the shadow aspects of life and can help illuminate them. This can be a powerful gift in your career or personal life. Don't shy away from exploring the depths, as this is where you'll find your greatest strength.
#
# *   **Balance Independence with Connection:** Your Aquarian Sun and Venus crave independence, while your Libra Ascendant and Scorpio Moon desire deep connection. Find healthy ways to maintain your personal freedom while nurturing meaningful relationships. Communicate your needs for space clearly and respectfully, and invest time and energy in building strong, authentic bonds.
#
# *   **Channel Your Intellectual Fire:** Your Aquarian energy is a wellspring of innovation. Use your sharp intellect to solve problems, contribute to your community, and explore new frontiers. Don't be afraid to think outside the box and to share your unique ideas. Your vision can be truly valuable.
#
# *   **Cultivate Emotional Vulnerability (Wisely):** While your Scorpio Moon desires deep emotional intimacy, it can also be guarded. Learning to be vulnerable with trusted individuals will allow you to experience the profound connections you crave. Start with small steps and build trust gradually.
#
# *   **Embrace Your Artistic and Intuitive Side:** Your Mercury in Pisces and the emotional depth of your Scorpio Moon suggest a natural affinity for the arts, creativity, and understanding subtle energies. Explore these avenues. Whether it's writing, music, art, or simply honing your intuition, these practices can bring you immense joy and a deeper understanding of yourself and the world.
#
# ### 5. Your Question: (If you had provided one, this section would be here)
#
# *(As no specific question was provided, I've focused on the comprehensive reading. If you have a question, please feel free to ask, and I can offer a more targeted response based on your chart.)*
#
# Anurag, your birth chart is a fascinating testament to your unique potential. You possess a brilliant mind, a deep emotional well, and a capacity for bringing about positive change. By understanding and integrating these powerful energies within you, you can navigate life with greater clarity, purpose, and fulfillment. Trust your intuition, embrace your individuality, and continue to explore the world with your characteristic curiosity and compassion.
#
# May your journey be blessed with wisdom, love, and continuous growth.
# ============================================================
