# %% [markdown]
# This is a GenAI based application, this app will take:
# Full name
# Date of birth
# Time of birth
# Birth place as inputs and Generate a Astological report of the user.

# %%
import os
import datetime
from typing import Dict
os.environ['API_KEY']= 'AIzaSyC5zwRMnxke1g-2SMkbA6BW5mBlu4BXRk8'

# %%
# %pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: google-api-python-client in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (2.47.0)
# Requirement already satisfied: protobuf in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (2.12.5)
# Requirement already satisfied: tqdm in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\thedo\appdata\local\programs\python\python313\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\thedo\appdata\roaming\python\python313\site-packages (from tqdm->google-generativeai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
name ='Anurag Awasthi'
birth_date = '1996-02-01'
birth_time= '10:23'
birth_place = 'Unnao, Uttar Pradesh'
question = 'Will my job get changed this year ? '

prompt = f"""You are an experienced astrologer providing a personalized astrological reading.

User Details:
- Name: {name}
- Birth Date: {birth_date}
- Birth Time: {birth_time if birth_time != "Unknown" else "Not provided"}
- Birth Place: {birth_place}
- Question/Focus: {question}

Please provide a comprehensive astrological reading that includes:

1. **Birth Chart Overview**: A general interpretation based on the birth date and location
2. **Sun Sign Analysis**: Personality traits and core characteristics
3. **Planetary Influences**: Key planetary positions and their meanings
4. **Life Guidance**: Practical insights and advice based on astrological indicators
5. **Answer to Question**: Specific response to the user's question if provided

Make the reading personal, insightful, and encouraging. Use astrological terminology appropriately but explain concepts clearly for someone who may not be deeply familiar with astrology.

Format your response with clear sections and make it engaging and meaningful."""

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['API_KEY'])

model = genai.GenerativeModel(model_name='gemini-2.5-flash-lite')


prediction = model.generate_content(prompt)

# %%
prediction.text
# Out:
# "Namaste Anurag, it's a pleasure to delve into your celestial blueprint. Your birth chart is a unique cosmic fingerprint, offering profound insights into your journey. Let's uncover the story the stars are telling you, especially concerning your career path this year.\n\n***\n\n## Your Cosmic Blueprint: An Astrological Reading for Anurag Awasthi\n\n**Born: February 1, 1996, 10:23 AM in Unnao, Uttar Pradesh**\n\nDear Anurag, the universe aligned in a very special way on the day of your birth. Your chart paints a picture of a thoughtful and driven individual, with a deep desire for stability and a strong work ethic. The energies present suggest a path of growth and transformation, and your question about a job change this year is one we can certainly explore through the lens of your astrological influences.\n\n### 1. Birth Chart Overview: The Foundation of Your Being\n\nYour birth chart, meticulously calculated for your specific time and place of birth, is the bedrock of this reading. It reveals the celestial snapshot at the moment you entered this world. Based on your birth details, your **Ascendant (Lagna)** is in **Aquarius**. This is a significant placement, as your Ascendant is what shapes how you present yourself to the world, your outward personality, and your general approach to life.\n\nWith an Aquarian Ascendant, you are likely perceived as an innovative, independent, and perhaps a bit unconventional individual. You have a keen intellect, a humanitarian streak, and a desire to contribute something unique to the world. You value freedom and may sometimes feel like an outsider, but you possess a strong sense of community and can be a wonderful friend and collaborator.\n\nYour **Moon sign**, which governs your emotions, inner world, and instincts, is in **Cancer**. This creates an interesting duality. While your Aquarian rising might make you appear detached or logical, your Cancer Moon reveals a deeply sensitive, nurturing, and emotionally driven core. You crave security, emotional connection, and a sense of belonging. You are likely very intuitive and can empathize deeply with others. This blend suggests you are someone who can think outside the box (Aquarius Ascendant) but also deeply cares about the well-being of those around you (Cancer Moon).\n\n### 2. Sun Sign Analysis: Your Core Radiance\n\nYour **Sun sign** is in **Aquarius**. This is your core identity, your ego, and your fundamental life force. As an Aquarius Sun, you are a visionary, a humanitarian, and a true original. You possess a sharp mind, a natural curiosity, and an inherent drive to break free from tradition and forge your own path.\n\n**Key Traits of an Aquarius Sun:**\n\n*   **Intellectual and Innovative:** You have a brilliant mind and are constantly seeking new ideas and solutions. You are often ahead of your time in your thinking.\n*   **Independent and Original:** You value your autonomy and don't like to be confined by rules or expectations. You have a unique perspective on life.\n*   **Humanitarian and Compassionate:** You have a strong sense of justice and a desire to improve the lives of others. You are often drawn to causes that benefit society.\n*   **Friendly and Social:** Despite your independent nature, you are usually quite sociable and enjoy interacting with a wide range of people. You are known for your broadmindedness.\n*   **Detached and Objective:** You can sometimes appear emotionally distant, as you tend to approach situations with logic and objectivity.\n\nYour Sun in Aquarius indicates a desire for work that stimulates your intellect, allows for creativity, and potentially has a positive impact on the world.\n\n### 3. Planetary Influences: The Cosmic Orchestra\n\nLet's look at some of the key players in your birth chart and what they signify:\n\n*   **Mercury in Aquarius:** This placement reinforces your intellectual prowess and communication style. Your mind is quick, sharp, and you express yourself in original and sometimes u ...

# %%
class AstrologyApp():
    '''Main class for astrology application.'''

    def __init__(self):
        self.user_info = {}

    

    def get_user_input(self)-> Dict[str, str]:
        '''Collect personal details from the user.'''

        print('=' * 60)
        print('Welcome to Astrology application.')
        print('=' * 60)

        name = input('Please enter your name: ').strip()
        dob = input('Enter your date of birth: ').strip()
        dot = input('Enter your birth time: ').strip()
        birth_place = input('Enter your birth place: ').strip()

        self.user_info= {
            'name':name,
            'dob': dob,
            'dot': dot,
            'birth_place': birth_place
        }

        return self.user_info

    def validate_user_inputs(self):

        if not self.user_info.get('name'):
            print('Error: Name is required.')
            return False

        if not self.user_info.get('dob'):
            print('Error: Date Of Birth is required.')
            return False
        
        try:
            datetime.strptime(self.user_info["dob"], "%Y-%m-%d")
        except ValueError:
            print("❌ Error: Invalid date format. Please use YYYY-MM-DD")
            return False

        if not self.user_info.get('birth_place'):
            print('Error: Birth Place is required.')
            return False

        return True


    def run(self):
        '''To run the application method'''
        user_data = self.get_user_input()

        # validate the user inputs:
        if not self.validate_user_inputs():
            return False

# %%
def main():
    '''Main pipeline of application'''
    app = AstrologyApp()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Welcome to Astrology application.
# ============================================================
