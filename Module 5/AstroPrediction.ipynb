# %% [markdown]
# This is a GenAI based application, this app will take:
# Full name
# Date of birth
# Time of birth
# Birth place as inputs and Generate a Astological report of the user.

# %%
import os
from datetime import datetime
from typing import Dict
os.environ['API_KEY']= 'AIzaSyC5zwRMnxke1g-2SMkbA6BW5mBlu4BXRk8'

# %%
# %pip install google-generativeai

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['API_KEY'])

model = genai.GenerativeModel(model_name='gemini-2.5-flash-lite')

# %%
class AstrologyApp():
    '''Main class for astrology application.'''

    def __init__(self):
        self.user_info = {}

    

    def get_user_input(self)-> Dict[str, str]:
        '''Collect personal details from the user.'''

        print('=' * 60)
        print('Welcome to Astrology application.')
        print('=' * 60)

        name = input('Please enter your name: ').strip()
        dob = input('Enter your date of birth: ').strip()
        dot = input('Enter your birth time: ').strip()
        birth_place = input('Enter your birth place: ').strip()

        self.user_info= {
            'name':name,
            'dob': dob,
            'dot': dot,
            'birth_place': birth_place
        }
        print(self.user_info)

        return self.user_info

    def validate_user_inputs(self):

        if not self.user_info.get('name'):
            print('Error: Name is required.')
            return False

        if not self.user_info.get('dob'):
            print('Error: Date Of Birth is required.')
            return False
        
        try:
            datetime.strptime(self.user_info["dob"], "%Y-%m-%d")
        except ValueError:
            print("Error: Invalid date format. Please use YYYY-MM-DD")
            return False

        if not self.user_info.get('birth_place'):
            print('Error: Birth Place is required.')
            return False

        return True

    def generate_ai_prompt(self)-> str:
        '''Generate a comprehensive prompt for astrological reading'''

        name= self.user_info['name']
        dob = self.user_info['dob']
        tob = self.user_info['dot']
        birth_place = self.user_info['birth_place']

        prompt = f"""You are an experienced astrologer providing a personalized astrological reading.

            User Details:
            - Name: {name}
            - Birth Date: {dob}
            - Birth Time: {tob if tob != "Unknown" else "Not provided"}
            - Birth Place: {birth_place}

            Please provide a comprehensive astrological reading that includes:

            1. **Birth Chart Overview**: A general interpretation based on the birth date and location
            2. **Sun Sign Analysis**: Personality traits and core characteristics
            3. **Planetary Influences**: Key planetary positions and their meanings
            4. **Life Guidance**: Practical insights and advice based on astrological indicators
            5. **Answer to Question**: Specific response to the user's question if provided

            Make the reading personal, insightful, and encouraging. Use astrological terminology appropriately but explain concepts clearly for someone who may not be deeply familiar with astrology.

            Format your response with clear sections and make it engaging and meaningful."""

        return prompt

    def get_llm_response(self, prompt: str)-> str:
        
        response = model.generate_content(prompt)
        print('Generating your astrological readings....')

        return response.text

    def display_readings(self, response: str):
        '''Method is to display the readings from the LLM '''
        print('\n' + '=' * 60)
        print('Your Astrological Readings:')
        print('=' * 60)
        print(response)
        print('=' * 60)

        # Option to save:
        save = input('Do you want to save this reading in a file ? (y/n): ').strip().lower()
        if save == 'y':
            self.save_readings_in_file(response)


    def save_readings_in_file(self, reading:str):
        '''Method to save these readings in a file'''
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f'astrology_readings_{self.user_info['name'].replace(' ', '_')}_{timestamp}.txt'

        try:
            with open(filename, 'w', encoding= 'utf-8') as f:
                f.write(f'Astrological Readings for :{self.user_info['name']}\n')
                f.write(f'Generated on {timestamp} \n')
                f.write("=" * 60 + "\n\n")
                f.write(f"Birth Details:\n")
                f.write(f"  Date: {self.user_info['dob']}\n")
                f.write(f"  Time: {self.user_info['tob']}\n")
                f.write(f"  Place: {self.user_info['birth_place']}\n")
                f.write("=" * 60 + "\n\n")
                f.write(reading)
            
            print(f"✅ Reading saved to: {filename}")
        except Exception as e:
            print('Unable to save the file.')


    def run(self):
        '''To run the application method'''
        self.get_user_input()

        # validate the user inputs:
        if not self.validate_user_inputs():
            print('Please correct the errors above and try again.')
            return 

        # Generate Prompt:
        prompt = self.generate_ai_prompt()

        # Generate LLM Response:
        response = self.get_llm_response(prompt)

        # Display readings:
        self.display_readings(response)

# %%
def main():
    '''Main pipeline of application'''
    app = AstrologyApp()
    app.run()

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Welcome to Astrology application.
# ============================================================
# {'name': 'anurag awasthi', 'dob': '1996-02-01', 'dot': '12:29', 'birth_place': 'Unnao, India'}
# Generating your astrological readings....
#
# ============================================================
# Your Astrological Readings:
# ============================================================
# Namaste Anurag! It's a pleasure to delve into the cosmic blueprint that shaped your journey. Your birth chart, cast for February 1st, 1996, at 12:29 PM in Unnao, India, offers a fascinating glimpse into your unique potential and life path. Let's explore what the stars have to say for you.
#
# ## Your Astrological Blueprint: A Personal Reading for Anurag Awasthi
#
# ### 1. Birth Chart Overview: A Foundation of Courage and Intellect
#
# Your birth chart paints a picture of a spirited and intelligent individual, driven by a strong desire to make your mark on the world. With your Sun in Aquarius, you possess an innovative and forward-thinking mind, often seeing beyond the conventional. The precise time and location of your birth place you firmly in **Aquarius rising**. This means you likely present yourself to the world with a sense of detachment, intellectual curiosity, and a desire for freedom and individuality. You are likely seen as original, progressive, and perhaps a little eccentric by others.
#
# The placement of your planets within the various houses of your chart further refines this overview. We see significant influences in areas related to communication, relationships, and your inner world, suggesting a rich tapestry of experiences and a journey of continuous learning and connection.
#
# ### 2. Sun Sign Analysis: The Humanitarian Visionary - Aquarius
#
# Your Sun sign is **Aquarius**, the Water Bearer. This is a sign of innovation, humanitarianism, and intellectual prowess. As an Aquarian, you are:
#
# *   **Independent and Original:** You march to the beat of your own drum and aren't afraid to challenge the status quo. Your ideas are often unique and ahead of their time.
# *   **Intellectually Curious:** You have a thirst for knowledge and are drawn to understanding how things work, especially in broader societal or scientific contexts.
# *   **Humanitarian and Altruistic:** You have a deep concern for humanity and a desire to contribute to the betterment of society. You are often driven by ideals and believe in fairness and equality.
# *   **Objective and Detached:** While you care deeply, you tend to approach situations with a logical and sometimes detached perspective, allowing you to see things clearly.
# *   **Friendly and Sociable:** You enjoy being part of a community and can form connections with a wide range of people. However, true intimacy might be something you approach with a certain level of independence.
#
# Your Aquarian energy fuels a desire to innovate and bring about positive change. You are a natural problem-solver, often finding unconventional solutions. Embrace your unique perspective, Anurag, as it's your greatest gift.
#
# ### 3. Planetary Influences: Key Cosmic Currents in Your Chart
#
# Let's explore some of the most significant planetary positions in your chart:
#
# *   **Ascendant (Rising Sign) in Aquarius:** As mentioned, this shapes your outward personality and how you approach life. You appear progressive, intellectual, and perhaps a bit aloof initially. You value freedom and independence in all aspects of your life.
# *   **Moon in Virgo:** This is a powerful placement for your emotional world and inner needs. Your Moon in Virgo signifies a need for order, analytical thinking, and practical solutions in your emotional life. You find comfort in logic and organization. You may be prone to overthinking your emotions or seeking perfection in your relationships and inner world. This can also make you very caring and attentive to details when it comes to loved ones.
# *   **Mercury in Aquarius:** This conjunction with your Sun amplifies your Aquarian traits. Your mind is sharp, innovative, and forward-thinking. You communicate your ideas with clarity and often in a unique way. You are drawn to intellectual discussions and may have a talent for understanding complex concepts.
# *   **Venus in Capricorn:** Your Venus here suggests that your approach to love, relationships, and values is characterized by responsibility, ambition, and a desire for long-term security. You are likely attracted to individuals who are mature, driven, and possess a sense of integrity. In relationships, you value loyalty, commitment, and a stable foundation. You may express affection through acts of service or by building something lasting together.
# *   **Mars in Sagittarius:** This placement fuels your drive and energy with a spirit of adventure, optimism, and a quest for knowledge. Your actions are often bold, enthusiastic, and guided by a philosophical outlook. You are eager to explore new ideas and experiences, and you have a strong sense of justice. However, be mindful of potential impulsiveness and the need to follow through on your energetic pursuits.
# *   **Jupiter in Capricorn:** Jupiter here brings expansive opportunities and growth through discipline, hard work, and a structured approach. You are likely to find success through practical endeavors, building a solid foundation, and demonstrating leadership. You have a strong work ethic and a deep understanding of responsibility. This placement can bring a sense of gravitas and authority to your endeavors.
# *   **Saturn in Aries:** Saturn in Aries signifies lessons around taking initiative, assertion, and leadership. You may have experienced challenges or a sense of caution in asserting yourself or taking bold action. However, with maturity, you learn to channel this energy into disciplined and pioneering efforts. You are learning to build courage and take on responsibility for your own ventures.
# *   **Chiron in Aquarius:** Your Chiron in Aquarius highlights a deep wound related to belonging, individuality, and societal acceptance. You may have felt like an outsider or struggled to fit in. The healing path lies in embracing your unique gifts, using your innovative spirit to help others find their place, and becoming a bridge between different groups. Your unique perspective is your strength, and by sharing it, you can heal yourself and others.
#
# ### 4. Life Guidance: Navigating Your Path with Wisdom
#
# Anurag, your chart reveals a powerful blend of intellectual curiosity and a deep-seated desire for structure and purpose. Here are some practical insights to guide you:
#
# *   **Embrace Your Uniqueness:** Your Aquarian Sun and Rising are your superpowers. Don't shy away from your original ideas or unconventional approaches. The world needs your innovative thinking.
# *   **Balance Intellect with Emotion:** While your Virgo Moon appreciates logic, remember to acknowledge and process your emotions. Journaling, mindful practices, or discussions with trusted friends can help you integrate your feelings with your analytical mind.
# *   **Build Meaningful Connections:** Your Venus in Capricorn suggests you value deep, committed relationships. Focus on building these with individuals who share your vision and values. Be patient and invest time in nurturing these bonds.
# *   **Channel Your Adventurous Spirit:** Your Mars in Sagittarius urges you to explore and learn. Seek out experiences that broaden your horizons, whether through travel, education, or engaging with new cultures and philosophies.
# *   **Discipline Fuels Growth:** Your Jupiter and Saturn placements emphasize the importance of hard work and discipline. Structure your efforts, set clear goals, and consistently work towards them. This is where you'll find significant success and fulfillment.
# *   **Be a Catalyst for Change:** Your Aquarian energy is meant to inspire and uplift. Look for opportunities to contribute to your community or to causes you believe in. Your unique perspective can be a powerful force for positive change.
#
# ### 5. Your Question
#
# As you haven't provided a specific question, I'll offer a general encouraging word. Anurag, you possess the intelligence, drive, and unique perspective to achieve remarkable things. Trust your intuition, embrace challenges as opportunities for growth, and never underestimate the power of your vision. The stars are aligned to support your journey of innovation, connection, and making a meaningful contribution to the world.
#
# May your journey be filled with wisdom, purpose, and profound joy.
#
# With warmest astrological blessings,
#
# [Your Astrologer Name/Title]
# ============================================================
# Unable to save the file.
