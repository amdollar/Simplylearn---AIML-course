# %%
from dotenv import find_dotenv, load_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model = 'gpt-4o-mini', temperature=0.3)

prompt = PromptTemplate.from_template('What is the best way of {topic}')

parser = StrOutputParser()

chain1 = prompt | llm
chain2 = prompt | llm | parser

# %%
# Execution Results: 

print('Without Output Parser: ')

result1 = chain1.invoke({
    'topic': 'Staying Young'
})

print(result1)

print('With Parser:')
result2= chain2.invoke({
    'topic': 'Reduce fat'
})

print(result2)
# Out:
# Without Output Parser:
# content='Staying young, both physically and mentally, involves a combination of healthy lifestyle choices, positive mindset, and proactive self-care. Here are some effective strategies:\n\n### Physical Health\n1. **Balanced Diet**: Eat a variety of fruits, vegetables, whole grains, lean proteins, and healthy fats. Antioxidant-rich foods can help combat aging.\n2. **Regular Exercise**: Engage in a mix of cardiovascular, strength training, and flexibility exercises. Aim for at least 150 minutes of moderate aerobic activity each week.\n3. **Stay Hydrated**: Drink plenty of water to maintain skin elasticity and overall health.\n4. **Adequate Sleep**: Aim for 7-9 hours of quality sleep each night to allow your body to repair and rejuvenate.\n5. **Sun Protection**: Use sunscreen and wear protective clothing to prevent skin damage from UV rays.\n\n### Mental and Emotional Well-being\n1. **Lifelong Learning**: Keep your mind sharp by learning new skills, reading, or taking up new hobbies.\n2. **Social Connections**: Maintain strong relationships with family and friends. Social interaction can improve mental health and longevity.\n3. **Stress Management**: Practice mindfulness, meditation, or yoga to reduce stress and promote emotional well-being.\n4. **Positive Attitude**: Cultivate a positive mindset and practice gratitude. A positive outlook can influence your overall health.\n\n### Preventive Care\n1. **Regular Check-ups**: Schedule routine health screenings and check-ups to catch potential issues early.\n2. **Avoid Harmful Habits**: Limit alcohol consumption, avoid smoking, and steer clear of recreational drugs.\n\n### Skin Care\n1. **Moisturize**: Use a good moisturizer to keep your skin hydrated.\n2. **Gentle Cleansing**: Cleanse your skin gently to avoid irritation and damage.\n\n### Stay Active and Engaged\n1. **Volunteer**: Helping others can provide a sense of purpose and fulfillment.\n2. **Travel and Explore**: New experiences can invigorate your spirit and keep life exciting.\n\n### Conclusion\nStaying young is not just about physical appearance; it’s about maintaining a vibrant, active, and fulfilling life. By focusing on both physical and mental health, you can enhance your quality of life and enjoy the journey as you age.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 470, 'prompt_tokens': 15, 'total_tokens': 485, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-D0SadOYNbaO6gPd7Swmmz98tw23ca', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019be0c0-7fa5-7660-bb73-7644fe68b8e8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 470, 'total_tokens': 485, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# With Parser:
# Reducing body fat effectively and sustainably typically involves a combination of dietary changes, physical activity, and lifestyle adjustments. Here are some key strategies:
#
# ### 1. **Balanced Diet:**
#    - **Caloric Deficit:** Consume fewer calories than you burn. Use a calorie calculator to determine your needs.
#    - **Whole Foods:** Focus on whole, unprocessed foods such as fruits, vegetables, lean proteins, whole grains, and healthy fats.
#    - **Protein Intake:** Increase protein consumption to help preserve muscle mass and promote satiety.
#    - **Healthy Fats:** Include sources of healthy fats (e.g., avocados, nuts, olive oil) while limiting saturated and trans fats.
#    - **Limit Sugar and Refined Carbs:** Reduce intake of sugary foods and beverages, as well as refined carbohydrates, which can lead to weight gain.
#
# ### 2. **Regular Physical Activity:**
#    - **Cardiovascular Exercise:** Engage in aerobic activities like walking, running, cycling, or swimming for at least 150 minutes per week.
#    - **Strength Training:** Incorporate resistance training 2-3 times per week to build muscle, which can increase metabolism.
#    - **High-Intensity Interval Training (HIIT):** Consider HIIT workouts, which can be effective for fat loss in shorter periods.
#
# ### 3. **Lifestyle Changes:**
#    - **Sleep:** Aim for 7-9 hours of quality sleep per night, as poor sleep can affect hormones that regulate hunger and appetite.
#    - **Stress Management:** Practice stress-reduction techniques such as yoga, meditation, or deep breathing, as stress can lead to emotional eating.
#    - **Stay Hydrated:** Drink plenty of water throughout the day, as hydration can help control hunger and support metabolism.
#
# ### 4. **Consistency and Patience:**
#    - **Set Realistic Goals:** Aim for gradual fat loss (1-2 pounds per week) rather than quick fixes.
#    - **Track Progress:** Keep a food diary or use apps to monitor your food intake and exercise.
#    - **Stay Committed:** Understand that fat loss takes time and requires a long-term commitment to lifestyle changes.
#
# ### 5. **Seek Professional Guidance:**
#    - Consider consulting a registered dietitian or a certified personal trainer for personalized advice and support.
#
# ### Conclusion:
# Remember that everyone's body responds differently to diet and exercise, so it’s essential to find a routine that works for you and is sustainable in the long run.
